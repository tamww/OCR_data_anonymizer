# %%
import pytesseract

# %%
import random, string, math, re, os
import fitz
from faker import Faker

# %%
from PIL import Image, ImageDraw, ImageSequence, ImageFont

# %%
import cv2
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
doc_text = []
fake = Faker("zh_tw")
colorList = fitz.utils.getColorList()
font_language = {1:'zh', 2:'en'}
doc_path = '2.pdf'
doc = fitz.open(doc_path)
extract_text = ''

# %%
for page in doc:
    img_list = page.get_images()
    for num, img in enumerate(img_list):
        img_name = f"./{i + 1}_{num + 1}.png" # save image
        pix = fitz.Pixmap(doc, img[0])  # image转pixmap
        if pix.n - pix.alpha >= 4:  # 如果差值大于等于4，需要转化后才能保存为png
            pix = fitz.Pixmap(fitz.csRGB, pix)
        pix.save(img_name) # 存储图片
        pix = None  # 释放Pixmap资源
#         image = Image.open(img_name)
        image = cv2.imread(img_name,0) #直接读为灰度图像
        image = 255 * np.array(image).astype('uint8')
        ret,thresh3 = cv2.threshold(image,127,255,cv2.THRESH_TRUNC)
        text = pytesseract.image_to_string(thresh3,"eng") # 调用tesseract，使用俄语库
        print(text)
        print(" ")

        # get text
#         text = pytesseract.image_to_string(image,'chi_tra') # 调用tesseract，使用俄语库
#         # get data
#         d = pytesseract.image_to_data(image)
#         print(d)
        
#         extract_text += text # 写入文本
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# G:\TMPTMP\ipykernel_11032\2506806519.py in <module>
#       2     img_list = page.get_images()
#       3     for num, img in enumerate(img_list):
# ----> 4         img_name = f"./{i + 1}_{num + 1}.png" # save image
#       5         pix = fitz.Pixmap(doc, img[0])  # image转pixmap
#       6         if pix.n - pix.alpha >= 4:  # 如果差值大于等于4，需要转化后才能保存为png
#
# NameError: name 'i' is not defined

# %%
pix = None  # 释放Pixmap资源
#     image = Image.open(img_name)
image = cv2.imread('4_4.png',0) #直接读为灰度图像
image = 255 * np.array(image).astype('uint8')
ret,thresh1 = cv2.threshold(image,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(image,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(image,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(image,127,255,cv2.THRESH_TOZERO)

# get text
# text = pytesseract.image_to_string(image,"chi_tra+eng") # 调用tesseract，使用俄语库
# print(" ")

# text = pytesseract.image_to_string(thresh1,"eng") # 调用tesseract，使用俄语库
# print(text)
# print(" ")
# text = pytesseract.image_to_string(thresh2,"eng") # 调用tesseract，使用俄语库
# print(text)
# print(" ")
text = pytesseract.image_to_string(thresh3,"eng") # 调用tesseract，使用俄语库
print(text)
print(" ")

# text = pytesseract.image_to_string(thresh4,"eng") # 调用tesseract，使用俄语库
# print(text)
# print(" ")
# Out:
# art I Details of Contributions (applicable to existing employee)
# R=ES HENS (WEAREE ER)
#
# — aT a Wa ad =p —
# FE = Jag = 3 0) we wo his
# KE te Tne | EET em me me | ei
#
# LL pany | CHEER | Swany | CHERRY i ey a
#
# iy bet is
# 1 | Chan Tai Man 2987654(3) 200 0 200 15/12/2012
# 2 | Ho Siu Ming X112233(0) 0 0 []
# 5
# I
# f
# c
# 5
# 0
# 3
# CE RT
# van
# wl 200 ”
# Pome koes: & fsiedcrepa 12455 (Gea pak SAM ay ene) - fnew
# fet ET SRTRE ine RR =m
# © yam
# EH
#
# u
#
# mst ries hen piso sr ear cor 14) cof 52 ean anos tye rks ihre.
#
# rr ee
#
# * SS ree neta
# ETN Ei Ce EEE
#
# 5 Pepe i mee se he ee oh Sh Pt 0508
# TERA RR BERR BWRL 0] (HERAER RIAA
#
# ey aut “ingot mtn Bert ea” (109 13513 Tn pT fn crt wi 0 rt.
# om
#
# TS
#
# Ee
#
# 10/01/2013
# SE
#
# [Pant 1H
#
# Fore

# %%
for page in doc:
    img_list = page.get_images()
    for num, img in enumerate(img_list):
        img_name = f"./{i + 1}_{num + 1}.png" # save image
        pix = fitz.Pixmap(doc, img[0])  # image转pixmap
        if pix.n - pix.alpha >= 4:  # 如果差值大于等于4，需要转化后才能保存为png
            pix = fitz.Pixmap(fitz.csRGB, pix)
        pix.save(img_name) # 存储图片
        pix = None  # 释放Pixmap资源
        image = Image.open(img_name)
        # get text
        text = pytesseract.image_to_string(image,'chi_tra') # 调用tesseract，使用俄语库
        # get data
        d = pytesseract.image_to_data(image)
        print(d)
        
        extract_text += text # 写入文本
#         os.remove(img_name)
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	1240	877	-1
# 2	1	1	0	0	0	102	128	876	87	-1
# 3	1	1	1	0	0	102	128	876	87	-1
# 4	1	1	1	1	0	102	128	876	67	-1
# 5	1	1	1	1	1	102	128	876	67	95.000000
# 5	1	1	1	1	2	620	170	358	25	95.000000
# 4	1	1	1	2	0	123	195	811	20	-1
# 5	1	1	1	2	1	123	195	183	20	95.000000
# 5	1	1	1	2	2	886	195	48	13	95.000000
# 2	1	2	0	0	0	381	176	319	54	-1
# 3	1	2	1	0	0	381	176	319	54	-1
# 4	1	2	1	1	0	462	176	158	13	-1
# 5	1	2	1	1	1	462	177	22	9	84.667419	BEA
# 5	1	2	1	1	2	488	176	32	11	84.667419	(MPF)
# 5	1	2	1	1	3	525	176	47	13	96.167816	Industry
# 5	1	2	1	1	4	577	176	43	10	96.816399	Scheme
# 4	1	2	1	2	0	470	189	141	13	-1
# 5	1	2	1	2	1	470	190	25	12	45.978828	RE
# 5	1	2	1	2	2	501	189	52	12	40.387367	(MAS)
# 5	1	2	1	2	3	560	190	51	11	30.446198	THR
# 4	1	2	1	3	0	381	205	319	12	-1
# 5	1	2	1	3	1	381	205	64	12	93.164398	Employer
# 5	1	2	1	3	2	439	196	6	29	34.979233	~
# 5	1	2	1	3	3	449	206	65	9	96.809616	Remittance
# ...

# %%
img_list = doc[0].get_images()
extract_text=''
for num, img in enumerate(img_list):
    img_name = f"./{i + 1}_{num + 1}.jpg" # save image
    pix = fitz.Pixmap(doc, img[0])  # image转pixmap
#     if pix.n - pix.alpha >= 4:  # 如果差值大于等于4，需要转化后才能保存为png
#     pix = fitz.Pixmap(fitz.csRGB, pix)
    pix.save(img_name) # 存储图片
    pix = None  # 释放Pixmap资源
#     image = Image.open(img_name)
    image = cv2.imread(img_name,0) #直接读为灰度图像
#     image = 255 * np.array(img).astype('uint8')
    ret,thresh1 = cv2.threshold(image,127,255,cv2.THRESH_BINARY)
    ret,thresh2 = cv2.threshold(image,127,255,cv2.THRESH_BINARY_INV)
    ret,thresh3 = cv2.threshold(image,127,255,cv2.THRESH_TRUNC)
    ret,thresh4 = cv2.threshold(image,127,255,cv2.THRESH_TOZERO)
    
    # get text
    text = pytesseract.image_to_string(thresh1,"chi_tra+eng") # 调用tesseract，使用俄语库
    print(" ")

    text = pytesseract.image_to_string(thresh1,"chi_tra+eng") # 调用tesseract，使用俄语库
    print(text)
    print(" ")
    text = pytesseract.image_to_string(thresh2,"chi_tra+eng") # 调用tesseract，使用俄语库
    print(text)
    print(" ")
    text = pytesseract.image_to_string(thresh3,"chi_tra+eng") # 调用tesseract，使用俄语库
    print(text)
    print(" ")

    text = pytesseract.image_to_string(thresh4,"chi_tra+eng") # 调用tesseract，使用俄语库
    print(text)
    print(" ")
    images = [thresh1,thresh2,thresh3,thresh4]
    for i in range(4):
        plt.subplot(1,1,i+1),plt.imshow(images[i],'gray')
        plt.xticks([]),plt.yticks([])
    plt.show()
    # get data
#     d = pytesseract.image_to_data(image)
#     print(d)

#     extract_text += text # 写入文本
# Out:
#
# BEA (MPF) industry scheme
# 和 生 中 HIH
# aa
# 念 主 ~ 付款 結算 書 (-RES
#
# Ba  Detols of Employer
# E-#9 kran
#
# 9888 8888.
#
# 四 7 兩
# " xya@abe.com 9272012 F atznon
# BEA (MPF) Industry Scheme No
# LEE 品 fAl 00.0,12.3,456 78-0.0.0,
# Partl Drtarh of Contibatins fapplable o new employeel
# LEE
# T 全 70.000
# e  |aewsemoT 70,000 otmanz
# : 1
# B !
# 國 |
# TT
#
# 如 meanu
# 如 | sersnue:
#
# 加
#
#
#
# BEA (MPF) industry scheme
# 和 生 中 HIH
# 人
# 念 主 ~ 付款 結算 書 (-RES
#
# Ba  Detols of Employer
# E-#9 kran
#
# 9888 8888.
#
# 四 7 兩
# " xya@abe.com 9272012 F atznon
# BEA (MPF) Industry Scheme No
# LEE 品 fAl 00.0,12.3,456 78-0.0.0,
# Partl Drtarh of Contibatins fapplable o new employeel
# LEE
# T 全 70.000
# e  |aewsemoT 70,000 otmanz
# : 1
# B !
# 國 |
# TT
#
# 如 meanu
# 如 | sersnue:
#
# 加
#
#
#
# BEA (WIPE) Indstry sanes
# FomRE SEHE 呻 l 訓 訓 」
#
# Employer Remance Statement (Relevant Employee)
# BT (RREE  EF
#
# 9888 8888
#
# " xya@abe.com
#
# 人 0422012 L avizaon
# 店 Appnduzuy Sene No
# ...

# %%
import numpy as np
pix = None  # 释放Pixmap资源
#     image = Image.open(img_name)
image = cv2.imread('4_4.png',0) #直接读为灰度图像
image = 255 * np.array(image).astype('uint8')
ret,thresh1 = cv2.threshold(image,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(image,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(image,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(image,127,255,cv2.THRESH_TOZERO)

# get text
# text = pytesseract.image_to_string(image,"chi_tra+eng") # 调用tesseract，使用俄语库
# print(" ")

# text = pytesseract.image_to_string(thresh1,"eng") # 调用tesseract，使用俄语库
# print(text)
# print(" ")
# text = pytesseract.image_to_string(thresh2,"eng") # 调用tesseract，使用俄语库
# print(text)
# print(" ")
text = pytesseract.image_to_string(thresh3,"eng") # 调用tesseract，使用俄语库
print(text)
print(" ")

# text = pytesseract.image_to_string(thresh4,"eng") # 调用tesseract，使用俄语库
# print(text)
# print(" ")
# Out:
# art I Details of Contributions (applicable to existing employee)
# R=ES HENS (WEAREE ER)
#
# — aT a Wa ad =p —
# FE = Jag = 3 0) we wo his
# KE te Tne | EET em me me | ei
#
# LL pany | CHEER | Swany | CHERRY i ey a
#
# iy bet is
# 1 | Chan Tai Man 2987654(3) 200 0 200 15/12/2012
# 2 | Ho Siu Ming X112233(0) 0 0 []
# 5
# I
# f
# c
# 5
# 0
# 3
# CE RT
# van
# wl 200 ”
# Pome koes: & fsiedcrepa 12455 (Gea pak SAM ay ene) - fnew
# fet ET SRTRE ine RR =m
# © yam
# EH
#
# u
#
# mst ries hen piso sr ear cor 14) cof 52 ean anos tye rks ihre.
#
# rr ee
#
# * SS ree neta
# ETN Ei Ce EEE
#
# 5 Pepe i mee se he ee oh Sh Pt 0508
# TERA RR BERR BWRL 0] (HERAER RIAA
#
# ey aut “ingot mtn Bert ea” (109 13513 Tn pT fn crt wi 0 rt.
# om
#
# TS
#
# Ee
#
# 10/01/2013
# SE
#
# [Pant 1H
#
# Fore

# %%
images = [thresh1,thresh2,thresh3,thresh4]

# %%
plt.figure(figsize = (100,100))
plt.imshow(images[0])

# %%
plt.figure(figsize = (100,100))
plt.imshow(images[1])

# %%
plt.figure(figsize = (100,100))

plt.imshow(images[2])

# %%
plt.figure(figsize = (100,100))

plt.imshow(images[3])

# %%
import paddlehub as hub
ocr = hub.Module(name="ch_pp-ocrv3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# G:\TMPTMP/ipykernel_27964/3949512149.py in <module>
# ----> 1 import paddlehub as hub
#       2 ocr = hub.Module(name="ch_pp-ocrv3")
#
# G:\Anaconda\Main\envs\Tensorflow_2_1_NEW\lib\site-packages\paddlehub\__init__.py in <module>
#      29 from paddlehub import env
#      30 from paddlehub.config import config
# ---> 31 from paddlehub import datasets
#      32 from paddlehub.finetune import Trainer
#      33 from paddlehub.utils import log, parser, utils
#
# G:\Anaconda\Main\envs\Tensorflow_2_1_NEW\lib\site-packages\paddlehub\datasets\__init__.py in <module>
#      13 # limitations under the License.
#      14
# ---> 15 from paddlehub.datasets.canvas import Canvas
#      16 from paddlehub.datasets.chnsenticorp import ChnSentiCorp
#      17 from paddlehub.datasets.esc50 import ESC50
#
# ...

# %%
def get_name(img,word_split=False):
    result = ocr.recognize_text(images=[img])
